# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import urllib.request
from bs4 import BeautifulSoup
import numpy as np

def extract_page_url(infomation_url):
    req = urllib.request.Request(infomation_url)
    html = urllib.request.urlopen(req)
    soup = BeautifulSoup(html, "html.parser")

    topic = soup.find_all('ui-button', attrs={'class': 'bar download'})
    article_urls = [tag['href'] for tag in topic.find_all('a', href=True)]
    article_titles = [tag.text for tag in topic.find_all('a', href=True)]
    return article_urls, article_titles

target_url = "https://covid19.apple.com/applications/covid19-mobility"
page_urls, page_titles = extract_page_url(target_url)

def get_csv_url(target_url):
        req = urllib.request.Request(target_url)
        html = urllib.request.urlopen(req)
        soup = BeautifulSoup(html, "html.parser")
        for atag in soup.find_all('a', href=True):
            if '全データのCSV' in atag.text:
                return atag['href']         

pdf_url = get_pdf_url(page_urls)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-fddd91fa7d46> in <module>
#      16
#      17 target_url = "https://covid19.apple.com/applications/covid19-mobility"
# ---> 18 page_urls, page_titles = extract_page_url(target_url)
#      19
#      20 def get_csv_url(target_url):
#
# <ipython-input-10-fddd91fa7d46> in extract_page_url(infomation_url)
#      11
#      12     topic = soup.find_all('ui-button', attrs={'class': 'bar download'})
# ---> 13     article_urls = [tag['href'] for tag in topic.find_all('a', href=True)]
#      14     article_titles = [tag.text for tag in topic.find_all('a', href=True)]
#      15     return article_urls, article_titles
#
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    2159         """Raise a helpful exception to explain a common code fix."""
# ...

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import urllib.request
from bs4 import BeautifulSoup
import numpy as np

def extract_page_url(infomation_url):
    req = urllib.request.Request(infomation_url)
    html = urllib.request.urlopen(req)
    soup = BeautifulSoup(html, "html.parser")

    topic = soup.find_all('div', attrs={'class': 'download-button-container'})[-1]
    article_urls = [tag['href'] for tag in topic.find_all('a', href=True)]
    article_titles = [tag.text for tag in topic.find_all('a', href=True)]
    return article_urls, article_titles

target_url = "https://covid19.apple.com/mobility"
page_urls, page_titles = extract_page_url(target_url)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-ee7b6643a37f> in <module>
#      16
#      17 target_url = "https://covid19.apple.com/mobility"
# ---> 18 page_urls, page_titles = extract_page_url(target_url)
#
# <ipython-input-19-ee7b6643a37f> in extract_page_url(infomation_url)
#      10     soup = BeautifulSoup(html, "html.parser")
#      11
# ---> 12     topic = soup.find_all('div', attrs={'class': 'download-button-container'})[-1]
#      13     article_urls = [tag['href'] for tag in topic.find_all('a', href=True)]
#      14     article_titles = [tag.text for tag in topic.find_all('a', href=True)]
#
# IndexError: list index out of range

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import urllib.request
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

df = pd.read_csv("https://covid19-static.cdn-apple.com/covid19-mobility-data/2021HotfixDev14/v3/en-us/applemobilitytrends-2020-11-17.csv")
df
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-24-f0aba617c99a> in <module>
#       6 import pandas as pd
#       7
# ----> 8 df = pd.read_csv("https://covid19-static.cdn-apple.com/covid19-mobility-data/2021HotfixDev14/v3/en-us/applemobilitytrends-2020-11-\*.csv")
#       9 df
#
# ...

# %%
import datetime
import time
dt_now = datetime.datetime.now()
print(dt_now.strftime('%Y年%m月%d日 %H:%M:%S'))
print(dt_now.strftime('%d'))

dt = dt_now.strftime('%d')
dt = int(dt) - 2
print(dt)
# Out:
# 2020年11月19日 14:59:59
# 19
# 17

# %%
import urllib.request
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import datetime
import time

dt_now = datetime.datetime.now()
dt = dt_now.strftime('%d')
dt = int(dt) - 2
dt

csv_url = "https://covid19-static.cdn-apple.com/covid19-mobility-data/2021HotfixDev14/v3/en-us/applemobilitytrends-2020-11-" + str(dt) + ".csv"
#print(df)   

df = pd.read_csv(csv_url)
#df
df.to_csv('covid_test.csv')
    
def open_covid_data():
    df1 = pd.read_csv("covid_test.csv")
    
open_covid_data()
print(df1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-46fd2d5a2159> in <module>
#      14 #print(df)
#      15
# ---> 16 df = pd.read_csv(csv_url)
#      17 #df
#      18 df.to_csv('covid_test.csv')
#
# ...

# %%
import urllib.request
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import datetime
import time

dt_now = datetime.datetime.now()
dt = dt_now.strftime('%d')
dt = int(dt) - 2
dt

def get_csv(csv_url):
    df = pd.read_csv(csv_url)
    #df
    df.to_csv('covid_test2.csv')
    print(df)
    return
    
csv_url = "https://covid19-static.cdn-apple.com/covid19-mobility-data/2021HotfixDev14/v3/en-us/applemobilitytrends-2020-11-" + str(dt) + ".csv"
# Out:
# <function get_csv at 0x7f5c5150c158>

# %%
# %matplotlib inline
import urllib.request
from bs4 import BeautifulSoup
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import datetime
import time


def get_csv(csv_url):
    try:
        df = pd.read_csv(csv_url)
        df.to_csv('covid_test.csv')
    except:
        print("Error")
    return

# appleのモビリティCSVのURLを作成
dt_now = datetime.datetime.now()
dt = dt_now.strftime('%d')
dt = int(dt) - 2
csv_url = "ahttps://covid19-static.cdn-apple.com/covid19-mobility-data/2021HotfixDev14/v3/en-us/applemobilitytrends-2020-11-" + str(dt) + ".csv"

#print(df)   
    
def open_covid_data():
    df1 = pd.read_csv("covid_test.csv")
    return

    
get_csv(csv_url)
open_covid_data()
#df1 = df1[df1['region'].str.contains('Japan')]
#df1 = df1[1:].set_index("day") 
df1
#df1.plot(figsize=(16,4))
# Out:
# Error
# /home/masakii/anaconda3/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3263: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#     Unnamed: 0        geo_type region transportation_type alternative_name  \
# 68          68  country/region  Japan             driving               日本
# 69          69  country/region  Japan             transit               日本
# 70          70  country/region  Japan             walking               日本
#
#    sub-region country  2020-01-13  2020-01-14  2020-01-15  ...  2020-11-08  \
# 68        NaN     NaN       100.0       97.94       99.14  ...      128.49
# 69        NaN     NaN       100.0       99.33      101.16  ...      119.06
# 70        NaN     NaN       100.0       96.07      102.01  ...      111.85
#
#     2020-11-09  2020-11-10  2020-11-11  2020-11-12  2020-11-13  2020-11-14  \
# ...
